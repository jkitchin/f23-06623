# %% [markdown]
# Getting to the solutions
# ------------------------
#
# First, run the first cell. This should create a folder called `share` in the root of your Jupyter HUB.

# %%
# %run ~/f23-06623/f23.py

# %% [markdown]
# You should now see
#
# ![image.png](attachment:a36b70f4-9af3-4b54-bc81-3cb25b564b98.png)

# %% [markdown]
# Inside the share directory is a directory for solutions. I will put solutions in this folder
